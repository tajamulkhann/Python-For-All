# %% [markdown]
# ## Importing Modules in Python: Modules and Packages
# In Python, modules and packages help organize and reuse code. Here's a comprehensive guide on how to import them.

# %% [markdown]
# #### What are Packages, Modules, Classes, Functions
#
# lets take an example of pandas,
# * package = pandas
# * IO Module = read, export
# * function = read_csv()
#
# ![image-2.png](attachment:image-2.png)

# %%
import math #module
math.sqrt(16) #function
# Out:
# 4.0

# %% [markdown]
# #### Import only Selected Functions

# %%
from math import sqrt, pi
print(sqrt(16))
print(sqrt(25))
print(pi)
# Out:
# 4.0
# 5.0
# 3.141592653589793

# %% [markdown]
# #### Alias

# %%
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %% [markdown]
# #### Import All Functions

# %%
from math import *
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %% [markdown]
# #### Import Custom Module
#
# 1. Create Folder package
# 2. Add File *double underscore* init *double underscore*.py to initialise package
# 3. Add another file e.g., math.py file mentioning function e.g. simple addition
# 4. Call the module and function - from package import math.addition

# %%
from package.maths import addition
addition(2,3)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from package.maths import addition
#       2 addition(2,3)
#
# ModuleNotFoundError: No module named 'package'

# %%
from package import maths
maths.addition(2,3)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from package import maths
#       2 maths.addition(2,3)
#
# ModuleNotFoundError: No module named 'package'

# %% [markdown]
# #### Conclusion
# Importing modules and packages in Python allows you to organize your code, reuse functionalities, and keep your projects clean and manageable. By understanding how to import modules, specific functions, and use relative imports within packages, you can structure your Python applications more effectively.
