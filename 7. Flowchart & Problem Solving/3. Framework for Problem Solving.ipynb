# %% [markdown]
# ## Process to Solve a Problem in DSA
#
# 1. Analyse your Problem - Input, Output, Constraints
# 2. Break down problem into smaller steps
# 3. Remember/enlist the concept
# 4. Take 2-3 examples - Clear Confusion/Gap
# 5. Wrie Pseudocode on a paper
# 6. Dry Run it once
# 7. Finally write down your solution

# %% [markdown]
# ![image.png](attachment:image.png)
