# %% [markdown]
# ## Flowcharts
#
# A flowchart is a graphical representation of steps of a process or a task using shapes like ovals, rectangles, and arrows.
#
# #### Components

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Flowchart to display even or odd numbers

# %% [markdown]
# ![image.png](attachment:image.png)
