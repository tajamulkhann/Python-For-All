# %% [markdown]
# ## Pandas
# Pandas is a Python library for data manipulation and analysis, providing data structures like DataFrame and Series for handling structured data efficiently.
#
# ### Index
#
# * Introduction to Pandas (Basic Commands, Use of Brackets, Applicatons, Data types, Data Structures)
# * Series (Create Series, Convert to Series, Indexing of Series, Operations on Series)
# * DataFrames (Import and Create DataFrame, Basic Data Analysis Commands),
#   * DF Column Commands = (Grabbing Columns, Create New Column, Drop Columns and Rows, Add/Shuffle Column Names, Column Str Function, Get Index, Remove Spaces)
#   * Indexing (With Loc, With Iloc), Slicing (With Loc, With iloc) and Fancy Indexing in DataFrames
#   * Filtering (Loc)  = (Single/ Multiple Filter and Preferred Column Filter)
#   * Selection in DataFrames = (Conditional Selection (without loc), Saving File, Reset Index of a File)
# * Missing Data (isna, dropna, fillna, ffill, bfill)
# * Sort Values (Single Column Level Sort, Multi-Column level Sort)
# * Operations (unique/nunique, count/value_counts, Round Function, Apply Self Function)
# * GroupBy (Single Level Grouping (specific column), Multi Level Grouping, Advanced Level Grouping)
# * Concatenatination, Merging and Joining (concept of inner, outer)
# * CrossTab and Pivot Tables (concept of aggfunc)
# * Plotting Bars (barh, bar, hist, pie)
# * Data Input and Output (csv, excel, HTML, SQL)

# %% [markdown]
# ### **1. Introduction to Pandas**
#
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and **manipulation tool**,
# built on top of the Python programming language.
#
# * The name of Pandas is derived from the word `Panel Data.` which refers to multi-dimensional structured datasets.
# * With Pandas we interact with Real World Data by Converting them into Data Frames
#
# * NumPy = `Arrays`
# * Pandas = `Series` and `Data Frame` (Large Arrays)

# %% [markdown]
# #### **Pandas Basic Commands**
#
# ---
#
# - ! pip install Pandas
# - ! pip uninstall Pandas
# - ! pip install --upgrade pandas
# - ! pip show pandas
# - `pd.__version__  #(major_number.minor_number.revision_number)` (Big update, Small update, Bug Fix)

# %% [markdown]
# #### **Use of Different Brackets**
#
# ---
#
# ```
# () - used for functions #randint(), #np.array()
#
# {} & [] - dictionary & sets
#
# [] - for indexing/slicing ... #df["col"], df.loc[], df.iloc[]
#
# ```

# %% [markdown]
# ### **Application of Pandas**
#
#
# ---
#
#
# ![Python-Pandas-Applications.webp](data:image/webp;base64,...)

# %% [markdown]
# #### **Pandas Data Types**
#
# ---
#
# * Categorical or object Data (Str or Str + int,float)
# * Numerical Data (Int or Float)

# %% [markdown]
# ![download (2).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### **Pandas Data Structures**
#
# ---

# %% [markdown]
# ![Python-Pandas-Module-1024x683.png.webp](data:image/webp;base64,...)

# %% [markdown]
# ### **2. Series**
# `single list with index`  `Combination of Np.Array and Index`
#
# *A Series is very similar to a NumPy array (in fact it is built on top of the NumPy array object). What differentiates the NumPy array from a Series, is that a Series can have axis labels, meaning it can be `indexed by a label`, instead of just a number location. It also doesn't need to hold numeric data, it can hold any arbitrary Python Object.*

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### **Creating Series**
#
#
# ---

# %%
labels = ['a','b','c']
my_list = [10,20,30]
my_tuple = (10,20,30)
arr = np.array([10,20,30])
d = {'a':10,'b':20,'c':30}

# %% [markdown]
# #### **Convert a list, numpy array or dictionary to a Series:**
#
#
# ---

# %%
pd.Series(data=my_list, index=labels)  #Specifying Data and Index
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(my_list,labels)   #Converting List into Series
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(my_tuple)       #Converting Tuple into Series
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(d)             #Converting Dict into Series
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(data= labels)   #Panda Series can hold object as well as numerical data
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.Series(index = labels, data = [sum,print,len])    # Even functions (although unlikely that you will use this)
# Out:
# a      <built-in function sum>
# b    <built-in function print>
# c      <built-in function len>
# dtype: object

# %% [markdown]
# #### **Indexing in Series**
#
#
# ---

# %%
a = pd.Series(data = [1,2,3,4], index = ['e','b','c','d'])
a
# Out:
# e    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
a['e']   #indexing of series
# Out:
# np.int64(1)

# %%
b = pd.Series(data = [5,6,7,8], index = ['e','b','c','d'])
b
# Out:
# e    5
# b    6
# c    7
# d    8
# dtype: int64

# %% [markdown]
# #### **Operations are then also done based off of index:**
#
# ---

# %%
a + b    #Adding two series
# Out:
# e     6
# b     8
# c    10
# d    12
# dtype: int64

# %% [markdown]
# ### **3. DataFrame**
# `Work horse of pandas`
#
#
#
# * Collection of Multiple Series
# * 2D tabular form data structure. (Index and Columns)
# * It is an internal data type of pandas required for data manipulation

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### **3.1 Importing and Creating DataFrames**
#
# - pd.read_csv('File_Name')  #Path
#
# - x = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data", header=None) #URL
#
# - x.to_csv('File_Name')  #To Save Csv File

# %% [markdown]
# ### **Downloading DataSets**

# %% [markdown]
# Kaggle https://www.kaggle.com/datasets
#
# UCL https://archive.ics.uci.edu/ml/datasets.php
#
# Analytics Case Search https://bit.ly/3oG5MbV

# %% [markdown]
# ### **Creating DataFrames**

# %%
from numpy.random import randn
df = pd.DataFrame(randn(5,4),index=['A', 'B', 'C', 'D', 'E'],columns=['W','X','Y','Z'])
df
# Out:
#           W         X         Y         Z
# A  2.117178 -0.385255 -0.415511 -0.208704
# B  0.055108 -0.663228 -0.840915  1.216813
# C  0.848602  0.260672  0.126797  0.335899
# D -1.058933  0.864944  0.416913  3.042148
# E  0.128278 -0.529706  1.781846  0.130175

# %% [markdown]
# **DataFrame Columns are just Series**

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['W'])  #Data Frame Columns are individual Series
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### **3.2 DataFrame Basic Commands**

# %%
dt = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data", header=None)
col = [                #Adding Column names in
        "age",
        "workclass",
        "fnlwgt",
        "education",
        "educationNum",
        "maritalStatus",
        "occupation",
        "relationship",
        "race",
        "sex",
        "capitalGain",
        "capitalLoss",
        "hoursPerWeek",
        "nativeCountry",
        "Above50K"
]
dt.columns = col
dt
# Out:
#        age          workclass  fnlwgt    education  educationNum  \
# 0       39          State-gov   77516    Bachelors            13
# 1       50   Self-emp-not-inc   83311    Bachelors            13
# 2       38            Private  215646      HS-grad             9
# 3       53            Private  234721         11th             7
# 4       28            Private  338409    Bachelors            13
# ...    ...                ...     ...          ...           ...
# 32556   27            Private  257302   Assoc-acdm            12
# 32557   40            Private  154374      HS-grad             9
# 32558   58            Private  151910      HS-grad             9
# 32559   22            Private  201490      HS-grad             9
# 32560   52       Self-emp-inc  287927      HS-grad             9
#
#              maritalStatus          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# * Head
#
#
#
# ---

# %%
dt.head()  #Giver Header of data
# Out:
#    age          workclass  fnlwgt   education  educationNum  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
# 3   53            Private  234721        11th             7
# 4   28            Private  338409   Bachelors            13
#
#          maritalStatus          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capitalGain  capitalLoss  hoursPerWeek   nativeCountry Above50K
# 0         2174            0            40   United-States    <=50K
# ...

# %% [markdown]
# * Tail
#
#
# ---

# %%
dt.tail()  #Gives Bottom of the Data
# Out:
#        age      workclass  fnlwgt    education  educationNum  \
# 32556   27        Private  257302   Assoc-acdm            12
# 32557   40        Private  154374      HS-grad             9
# 32558   58        Private  151910      HS-grad             9
# 32559   22        Private  201490      HS-grad             9
# 32560   52   Self-emp-inc  287927      HS-grad             9
#
#              maritalStatus          occupation relationship    race      sex  \
# 32556   Married-civ-spouse        Tech-support         Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32558              Widowed        Adm-clerical    Unmarried   White   Female
# 32559        Never-married        Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        capitalGain  capitalLoss  hoursPerWeek   nativeCountry Above50K
# ...

# %% [markdown]
# * Describe
#
# ---

# %%
dt.describe()
# Out:
#                 age        fnlwgt  educationNum   capitalGain   capitalLoss  \
# count  32561.000000  3.256100e+04  32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05     10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05      2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04      1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05      9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05     10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05     12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06     16.000000  99999.000000   4356.000000
#
#        hoursPerWeek
# count  32561.000000
# mean      40.437456
# std       12.347429
# min        1.000000
# 25%       40.000000
# 50%       40.000000
# 75%       45.000000
# max       99.000000

# %% [markdown]
# * Info
#
#
# ---

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            32561 non-null  int64
#  1   workclass      32561 non-null  object
#  2   fnlwgt         32561 non-null  int64
#  3   education      32561 non-null  object
#  4   educationNum   32561 non-null  int64
#  5   maritalStatus  32561 non-null  object
#  6   occupation     32561 non-null  object
#  7   relationship   32561 non-null  object
#  8   race           32561 non-null  object
#  9   sex            32561 non-null  object
#  10  capitalGain    32561 non-null  int64
#  11  capitalLoss    32561 non-null  int64
#  12  hoursPerWeek   32561 non-null  int64
#  13  nativeCountry  32561 non-null  object
#  14  Above50K       32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# * Sample
#
# ---

# %%
dt.sample()
# Out:
#        age          workclass  fnlwgt education  educationNum  \
# 22596   51   Self-emp-not-inc  246820   HS-grad             9
#
#              maritalStatus     occupation relationship    race    sex  \
# 22596   Married-civ-spouse   Craft-repair      Husband   White   Male
#
#        capitalGain  capitalLoss  hoursPerWeek   nativeCountry Above50K
# 22596         7298            0            48   United-States     >50K

# %% [markdown]
# #### **3.3 DataFrame Column Commands**

# %% [markdown]
# 1. **Grabbing columns:**
#
#
# ---

# %%
df.head()
# Out:
#           W         X         Y         Z
# A  2.117178 -0.385255 -0.415511 -0.208704
# B  0.055108 -0.663228 -0.840915  1.216813
# C  0.848602  0.260672  0.126797  0.335899
# D -1.058933  0.864944  0.416913  3.042148
# E  0.128278 -0.529706  1.781846  0.130175

# %%
df['Z'] #grabbing single Column
# Out:
# A   -0.208704
# B    1.216813
# C    0.335899
# D    3.042148
# E    0.130175
# Name: Z, dtype: float64

# %%
df.Z #Not Recommended
# Out:
# A   -0.208704
# B    1.216813
# C    0.335899
# D    3.042148
# E    0.130175
# Name: Z, dtype: float64

# %%
df[['W','X','Y','Z']] #grabbing Multiple Columns
# Out:
#           W         X         Y         Z
# A  2.117178 -0.385255 -0.415511 -0.208704
# B  0.055108 -0.663228 -0.840915  1.216813
# C  0.848602  0.260672  0.126797  0.335899
# D -1.058933  0.864944  0.416913  3.042148
# E  0.128278 -0.529706  1.781846  0.130175

# %% [markdown]
# 2. **Creating a new column:**
#
# ---

# %%
df['New'] = df['W'] + df['Y']
df
# Out:
#           W         X         Y         Z       New
# A  2.117178 -0.385255 -0.415511 -0.208704  1.701668
# B  0.055108 -0.663228 -0.840915  1.216813 -0.785807
# C  0.848602  0.260672  0.126797  0.335899  0.975399
# D -1.058933  0.864944  0.416913  3.042148 -0.642020
# E  0.128278 -0.529706  1.781846  0.130175  1.910124

# %% [markdown]
#  **Removing Columns**
#
# ---

# %%
df.drop(columns = ['W', 'X'])
# Out:
#           Y         Z       New
# A -0.415511 -0.208704  1.701668
# B -0.840915  1.216813 -0.785807
# C  0.126797  0.335899  0.975399
# D  0.416913  3.042148 -0.642020
# E  1.781846  0.130175  1.910124

# %% [markdown]
# `Removing Columns mentioning Axis`

# %%
df.drop('New', axis = 1, inplace = True)     #Use of Inplace

# %%
dt
# Out:
#        age          workclass  fnlwgt    education  educationNum  \
# 0       39          State-gov   77516    Bachelors            13
# 1       50   Self-emp-not-inc   83311    Bachelors            13
# 2       38            Private  215646      HS-grad             9
# 3       53            Private  234721         11th             7
# 4       28            Private  338409    Bachelors            13
# ...    ...                ...     ...          ...           ...
# 32556   27            Private  257302   Assoc-acdm            12
# 32557   40            Private  154374      HS-grad             9
# 32558   58            Private  151910      HS-grad             9
# 32559   22            Private  201490      HS-grad             9
# 32560   52       Self-emp-inc  287927      HS-grad             9
#
#              maritalStatus          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# 4. **Removing Rows**
#
# ---

# %% [markdown]
# `Removing Rows mentioning Axis`

# %%
df.drop('A', axis = 0)
# Out:
#           W         X         Y         Z
# B  0.055108 -0.663228 -0.840915  1.216813
# C  0.848602  0.260672  0.126797  0.335899
# D -1.058933  0.864944  0.416913  3.042148
# E  0.128278 -0.529706  1.781846  0.130175

# %% [markdown]
# `Removing Row mentioning index`

# %%
df.drop(index = ['A','B'])
# Out:
#           W         X         Y         Z
# C  0.848602  0.260672  0.126797  0.335899
# D -1.058933  0.864944  0.416913  3.042148
# E  0.128278 -0.529706  1.781846  0.130175

# %% [markdown]
# 5. **Adding Column Names**
#
# ---

# %%
df.columns
# Out:
# Index(['W', 'X', 'Y', 'Z'], dtype='object')

# %% [markdown]
# 6. **Column String Functions**
#
# ---

# %%
dt

# %%
dt.education.str.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1049/1986854197.py in ?()
# ----> 1 df.education.str.upper()
#
# ~/.local/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'education'

# %% [markdown]
# 7. **Get Index names**
#
# ---

# %%
df.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %% [markdown]
# 8. **Removing space in Columns**
#
# ---

# %% [markdown]
# * **From all elements**

# %%
df.replace(to_replace=" ", value="") # it will only work on values and not column names

# %% [markdown]
# *   **From Columns Headers**

# %%
df.columns = [col.strip() for col in df.columns]

# %% [markdown]
# *   **From Columns Elements**

# %%
df.education.str.strip()

# %% [markdown]
# ### **3.4 Indexing and Slicing in DataFrames**

# %% [markdown]
# #### **3.4.1 Indexing**
#
#
# ---
#
#
# is done in pandas with the help of `loc and iloc` command

# %% [markdown]
# #### **Loc Indexing** (*Location*)
# deals with Name Indexing
#
#
#
# ```
# # Syntax = df.loc[df.loc[row_name, col_name]
# ```
#
#
#
# ---

# %%
df.head()
# Out:
#           W         X         Y         Z
# A -0.586651  1.249663  0.755362  0.621232
# B -0.110828  1.364613 -0.103515  0.140733
# C -0.901232 -0.395844 -0.902969 -1.402054
# D  1.087844  1.512054 -1.252321  0.034545
# E -0.568000  0.776997  0.508880 -0.494301

# %%
df.loc['A', 'W']  #Grab for 1 element  #Golden Rules are Excluded
# Out:
# -0.5866510488872496

# %% [markdown]
# #### **iLoc Indexing** (*Integer Location*)
# deals with Integer Location Indexing
#
#
# ```
# Syntax - df.iloc[row_num, col_num]
# ```
#
#
#
#
# ---

# %%
df.iloc[0, 0]  #Grab for 1 element  #Golden Rules are Considered

# %% [markdown]
# Editing particular cell in Pandas with iloc
#
#
# ---

# %%
df.iloc[1, 2] = 83311

# %%
df

# %% [markdown]
# #### **3.4.2 Slicing**
#
# is done is pandas with the help of loc and iloc command
#
#
#
#
# ---

# %% [markdown]
# #### **Loc** (*Location*)
#
#
# *   deals with Name Slicing
# *   **does not include stop in range rule because that rule is limited to Numbers**
#
#
#
#
#
# ```
# Syntax - df.loc[start_row_name:stop_row_name start_col_name:stop_col_name]
#
# ```
#
#
#
# ---

# %%
df.head()
# Out:
#           W         X         Y         Z
# A -0.586651  1.249663  0.755362  0.621232
# B -0.110828  1.364613 -0.103515  0.140733
# C -0.901232 -0.395844 -0.902969 -1.402054
# D  1.087844  1.512054 -1.252321  0.034545
# E -0.568000  0.776997  0.508880 -0.494301

# %%
df.loc['A':'C', 'W':'X'] #name indexing
# Out:
#           W         X
# A -0.586651  1.249663
# B -0.110828  1.364613
# C -0.901232 -0.395844

# %% [markdown]
# #### **iLoc** (*Integer Location*)
#
#
# *   deals with Number Slicing
# *   **includes stop in range rule**
#
#
#
#
#
# ```
# Syntax - df.loc[start_row_number:stop_row_number start_col_number:stop_col_number]
#
# ```
#
#
#
# ---

# %%
df.iloc[:3,:2]          #integer indexing
# Out:
#           W         X
# A -0.586651  1.249663
# B -0.110828  1.364613
# C -0.901232 -0.395844

# %% [markdown]
# #### **3.4.3 Fancy Indexing**
#
#
#
# ---

# %%
df.iloc[[1,2,3]] #use double square brackets always
# Out:
#           W         X         Y         Z
# B -0.110828  1.364613 -0.103515  0.140733
# C -0.901232 -0.395844 -0.902969 -1.402054
# D  1.087844  1.512054 -1.252321  0.034545

# %% [markdown]
# #### **3.4.4 More Index Details**
#
# ---
#
#
# Let's discuss some more features of indexing, including resetting the index or setting it something else. We'll also talk about index hierarchy!

# %%
df
# Out:
#           W         X         Y         Z
# A -0.586651  1.249663  0.755362  0.621232
# B -0.110828  1.364613 -0.103515  0.140733
# C -0.901232 -0.395844 -0.902969 -1.402054
# D  1.087844  1.512054 -1.252321  0.034545
# E -0.568000  0.776997  0.508880 -0.494301

# %%
newind = 'CA NY WY OR CO'.split()

# %%
df['States'] = newind

# %%
df
# Out:
#           W         X         Y         Z States
# A -0.586651  1.249663  0.755362  0.621232     CA
# B -0.110828  1.364613 -0.103515  0.140733     NY
# C -0.901232 -0.395844 -0.902969 -1.402054     WY
# D  1.087844  1.512054 -1.252321  0.034545     OR
# E -0.568000  0.776997  0.508880 -0.494301     CO

# %% [markdown]
# ### **3.5 Filtering and Selection in DataFrames**

# %%
dt = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data", header=None)

# %%
col = [                #Adding Column names in
        "age",
        "workclass",
        "fnlwgt",
        "education",
        "educationNum",
        "maritalStatus",
        "occupation",
        "relationship",
        "race",
        "sex",
        "capitalGain",
        "capitalLoss",
        "hoursPerWeek",
        "nativeCountry",
        "Above50K"
]

# %%
dt.columns = col

# %%
dt.describe()
# Out:
#                 age        fnlwgt  educationNum   capitalGain   capitalLoss  \
# count  32561.000000  3.256100e+04  32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05     10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05      2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04      1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05      9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05     10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05     12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06     16.000000  99999.000000   4356.000000
#
#        hoursPerWeek
# count  32561.000000
# mean      40.437456
# std       12.347429
# min        1.000000
# 25%       40.000000
# 50%       40.000000
# 75%       45.000000
# max       99.000000

# %% [markdown]
# #### **Filtering (Loc)**
#
#
#
# ```
# Syntax - df.loc[conditon_for_filtering_rows, col_name]
# ```
#
#
#
#
# ---

# %% [markdown]
# #### 1. **Apply Single Filter:**
#
# ```
# Syntax - df.loc[(cond_1), col_name]
# ```
#
# ---

# %% [markdown]
# Get all people with age < 20 ?
#
#
#
# ---

# %%
dt.loc[(dt.age < 20), :]

# %% [markdown]
# #### 2. **Apply Multiple Filters:**
#
#
# ```
# Syntax - df.loc[(cond_1) & (cond_2), col_names[link text](https:// [link text](https:// [link text](https://)))]
#
# Can use
#
# * & == And
# * | == OR
# ```
#
#
# ---

# %%
dt.loc[(dt.age < 20) & (dt.education == ' HS-grad') & (dt.sex == ' Female'), :]

# %% [markdown]
# #### **3. Apply Multiple Filters with Prefered Columns**

# %%
dt2 = dt.loc[(dt.age <20) & (dt.sex == ' Female') & (dt.education == ' HS-grad'), ['age', 'education', 'sex']]
dt2

# %% [markdown]
# #### **4. Conditional Selection**
#
# ---
#
#
#
# An important feature of pandas is conditional selection using bracket notation, very similar to numpy:

# %%
dt[dt['age']>0]

# %%
dt[(dt['age']>18) & (dt['hoursPerWeek'] > 40)]

# %% [markdown]
# #### **5. Saving Filtered Data As Individual File**
#
# ---

# %%
dt2 = dt.loc[(dt.age <20) & (df.sex == ' Female') & (df.education == ' HS-grad'), ['age', 'education', 'sex']]

# %%
dt2.to_csv('Yay')

# %% [markdown]
# #### 6. **Resetting Index of a File**
#
# ---

# %%
dt2.reset_index()

# %%
dt2.reset_index(drop=True)  #Dropping Index

# %%
dt2.set_index('age', inplace = True)   #Setting Index

# %% [markdown]
# ### **4. Missing Data**
# `Let's show a few convenient methods to deal with Missing Data in pandas:`

# %%
import numpy as np
import pandas as pd

dx = pd.DataFrame({'A':[1,2,np.nan],
                  'B':[5,np.nan,np.nan],
                  'C':[1,2,3]})

dx
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %% [markdown]
# * **Show NA**

# %%
dx.isna()
# Out:
#        A      B      C
# 0  False  False  False
# 1  False   True  False
# 2   True   True  False

# %% [markdown]
# * **Drop NA**

# %%
dx.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df.dropna(thresh=2)  #Doubt

# %% [markdown]
# * **Custom Fill**

# %%
df.fillna(value='FILL VALUE')
# Out:
#             A           B  C
# 0         1.0         5.0  1
# 1         2.0  FILL VALUE  2
# 2  FILL VALUE  FILL VALUE  3

# %%
df['A'].fillna(value=df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
df['A'].fillna(value=df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %% [markdown]
# * **Forward Fill**

# %%
df.A.ffill() #In ffill take forward Value to fill NaN

# %% [markdown]
# * **Back Fill**

# %%
df.A.bfill()  #In bfill take backward Value to fill NaN

# %% [markdown]
# ###  **5. Sort Values**
#
# `Sorting Data in Asc or Desc Order`

# %% [markdown]
# Single Column Level Sort

# %%
# Sort the DF basis age
dt.sort_values(by="age")

# %% [markdown]
# Multi-Column level Sort

# %%
dt.sort_values(by=["sex", 'age'], ascending=[False, True]) #by default ascending is True
# Out:
#        age workclass  fnlwgt      education  educationNum  \
# 262     17   Private  245918           11th             7
# 271     17   Private  191260            9th             5
# 335     17   Private  270942        5th-6th             3
# 371     17   Private   89821           11th             7
# 421     17   Private  175024           11th             7
# ...    ...       ...     ...            ...           ...
# 19212   90   Private  139660   Some-college            10
# 20610   90   Private  206667        Masters            14
# 24238   90         ?  166343        1st-4th             2
# 25303   90         ?  175444        7th-8th             4
# 32277   90   Private  313749        HS-grad             9
#
#              maritalStatus          occupation     relationship    race  \
# 262          Never-married       Other-service        Own-child   White
# 271          Never-married       Other-service        Own-child   White
# ...

# %% [markdown]
# ### **6. Operations**

# %% [markdown]
# #### **1. Unique and Nunique**
#
#
# ---
#
#
#
# * unique returns str values
# * nunique returns int values

# %%
dt.education.nunique()   #Numerical Data
# Out:
# 16

# %%
dt.education.unique()    #Categorical Data
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %% [markdown]
# #### **2. Count and Value_Counts**
#
#
# ---
#
#
# * **Count()** is what tells us the total number of rows
#
# * **Value_counts()** categorizes the types of categories in that columns and tells the count for each and every category.

# %%
# Count(num of people) in each education ?
dt.education.value_counts()

# %%
dt.education.count() #Counts Number in whole

# %% [markdown]
# ---
#
#
# #### **Interview Question**
#
#
# ---
# Convert all numerical education to aplha .. example (10th - Tenth)
#
# ---

# %%
dt['education'].replace('10th','Tenth', regex= True) #regex (Regular Expression) defines search pattern

# %% [markdown]
# #### **3. Round Function**
#
# ---

# %%
import numpy as np

# %%
T = pd.DataFrame(columns=["int", 'dec', 'both'])
T["int"] = np.random.randint(0, 100, 10)
T['dec'] = np.random.rand(10)
T['both'] = np.random.randint(0, 100, 10) + np.random.rand(10)

# %%
T.dec.round(2) #For Single Column

# %%
T.round({"dec": 2, 'both': 1}) #For Multiple Columns

# %% [markdown]
# #### **4. Applying Functions**
#
# ---

# %%
import pandas as pd
y = pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc','def','ghi','xyz']})
y.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
def times2(x):
    return x*2

# %%
y['col1'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
y['col3'].apply(len)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# Name: col3, dtype: int64

# %%
y['col1'].sum()
# Out:
# 10

# %% [markdown]
# ### **7. Group By**
#
#  you can use the .groupby() method to group rows together based off of a column name
#
# `Syntax - df.grouby('col_to_be_grouped').agg_fun`

# %%
P = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data", header=None)
col = [                #Adding Column names in
        "age",
        "workclass",
        "fnlwgt",
        "education",
        "educationNum",
        "maritalStatus",
        "occupation",
        "relationship",
        "race",
        "sex",
        "capitalGain",
        "capitalLoss",
        "hoursPerWeek",
        "nativeCountry",
        "Above50K"
]
P.columns = col
P.head()
# Out:
#    age          workclass  fnlwgt   education  educationNum  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
# 3   53            Private  234721        11th             7
# 4   28            Private  338409   Bachelors            13
#
#          maritalStatus          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capitalGain  capitalLoss  hoursPerWeek   nativeCountry Above50K
# 0         2174            0            40   United-States    <=50K
# ...

# %% [markdown]
# * **Single Level Grouping**
#
# ---

# %%
P.groupby("education").mean()

# %% [markdown]
# * Specific Column Grouping

# %%
P.groupby("workclass").mean()["age"]
# Out:
# workclass
#  ?                   40.960240
#  Federal-gov         42.590625
#  Local-gov           41.751075
#  Never-worked        20.571429
#  Private             36.797585
#  Self-emp-inc        46.017025
#  Self-emp-not-inc    44.969697
#  State-gov           39.436055
#  Without-pay         47.785714
# Name: age, dtype: float64

# %%
P.groupby('sex')['age'].mean()

# %% [markdown]
# * Group wise Size

# %%
P.groupby('nativeCountry').size() # size - num of rows in that category!

# %% [markdown]
# * **Multi Level Grouping**
#
#
# ---

# %%
P.groupby(["education", 'sex'])["age"].mean()
# Avg Female in 10th is 35.4 only
# Avg Male - 38.3

# %% [markdown]
# * **Advanced Level Grouping**
#
#
# ---
#
# Syntax
# `x.groupby('col_to_be_grouped').agg(new_col_name = ("colname", 'func'), new_col_name2 = ("colname2", 'func2'))`

# %%
P.groupby(["education"]).agg(sum_capitalGain = ("capitalGain", 'sum'),
                              sum_capitalLoss= ("capitalLoss", 'sum'),
                              avg_age = ("age", 'mean')).reset_index()

# %% [markdown]
# ### **8. Merging, Joining and Concatenating**
#
# There are 3 main ways of combining DataFrames together: Merging, Joining and Concatenating. In this lecture we will discuss these 3 methods with examples.
#
# ____

# %%
import pandas as pd

df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7])

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# #### 1. **Concatenation**
#
#
# ---
#
#
#
# Concatenation basically glues together DataFrames. Keep in mind that dimensions should match along the axis you are concatenating on. You can use **pd.concat** and pass in a list of DataFrames to concatenate together:

# %%
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3],axis=1) #Along the Column
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %% [markdown]
# #### 2. **Merge**
#
#
# ---
#
#
# The **merge** function allows you to merge DataFrames together using a similar logic as merging SQL Tables together. For example:
#
# `pd.merge(x,y, how= [inner,outer, left, right] , on = [Common Column]`

# %%
import numpy as np
import pandas as pd

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3'],
                     'C': ['C0', 'C1', 'C2', 'C3']})

right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#   key   A   B   C
# 0  K0  A0  B0  C0
# 1  K1  A1  B1  C1
# 2  K2  A2  B2  C2
# 3  K3  A3  B3  C3

# %%
right
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(left, right, how= 'inner', on = 'key' )
# Out:
#   key   A   B C_x C_y   D
# 0  K0  A0  B0  C0  C0  D0
# 1  K1  A1  B1  C1  C1  D1
# 2  K2  A2  B2  C2  C2  D2
# 3  K3  A3  B3  C3  C3  D3

# %%
pd.merge(left, right, how= 'inner', on = 'C' )

# %% [markdown]
# #### 3. **Joining**
# Joining is a convenient method for combining the columns of two potentially differently-indexed DataFrames into a single result DataFrame.**bold text**

# %%
left1 = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2'])

right2 = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
left1.join(right2)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
left1.join(right2, how='outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %% [markdown]
# ### **9. Cross Tab and Pivot Tables**

# %% [markdown]
# #### **9.1  CrossTab**
#
# ---
#
# Aggregation at both Column and Row level unlike Groupby which takes only one argument
#
# `Syntax = pd.crosstab(index = x.col1, columns=x.col2, values=x.age, aggfunc="mean")`

# %%
dk = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data", header=None)
col = [                #Adding Column names in
        "age",
        "workclass",
        "fnlwgt",
        "education",
        "educationNum",
        "maritalStatus",
        "occupation",
        "relationship",
        "race",
        "sex",
        "capitalGain",
        "capitalLoss",
        "hoursPerWeek",
        "nativeCountry",
        "Above50K"
]
dk.columns = col
dk.sample(3)
# Out:
#        age workclass  fnlwgt      education  educationNum  \
# 11987   23   Private  107801      Bachelors            13
# 29528   20   Private  164441        HS-grad             9
# 15244   49   Private   84298   Some-college            10
#
#              maritalStatus      occupation relationship    race      sex  \
# 11987        Never-married    Adm-clerical    Own-child   White   Female
# 29528        Never-married   Other-service    Own-child   Black     Male
# 15244   Married-civ-spouse           Sales      Husband   White     Male
#
#        capitalGain  capitalLoss  hoursPerWeek   nativeCountry Above50K
# 11987            0            0            20   United-States    <=50K
# 29528            0            0            40   United-States    <=50K
# 15244         7688            0            40   United-States     >50K

# %%
pd.crosstab(index = dk.education, columns=dk.sex, values=dk.age, aggfunc="mean")
# Out:
# sex               Female       Male
# education
#  10th          35.447458  38.346395
#  11th          30.546296  33.407806
#  12th          29.756944  33.117647
#  1st-4th       48.521739  45.245902
#  5th-6th       44.369048  42.385542
#  7th-8th       49.693750  48.034979
#  9th           42.131944  40.643243
#  Assoc-acdm    36.361045  38.046440
#  Assoc-voc     37.872000  38.939909
#  Bachelors     35.635578  40.321734
#  Doctorate     45.325581  48.327217
#  HS-grad       38.678171  39.115736
#  Masters       43.074627  44.490312
#  Preschool     41.750000  43.228571
#  Prof-school   40.195652  45.611570
#  Some-college  33.740556  37.017391

# %%
pd.crosstab(index=dk.education, columns=dk.sex, values=dk.age, aggfunc=["mean", 'sum'])
# Out:
#                     mean                sum
# sex               Female       Male  Female    Male
# education
#  10th          35.447458  38.346395   10457   24465
#  11th          30.546296  33.407806   13196   24822
#  12th          29.756944  33.117647    4285    9571
#  1st-4th       48.521739  45.245902    2232    5520
#  5th-6th       44.369048  42.385542    3727   10554
#  7th-8th       49.693750  48.034979    7951   23345
#  9th           42.131944  40.643243    6067   15038
#  Assoc-acdm    36.361045  38.046440   15308   24578
#  Assoc-voc     37.872000  38.939909   18936   34345
#  Bachelors     35.635578  40.321734   57694  150642
#  Doctorate     45.325581  48.327217    3898   15803
#  HS-grad       38.678171  39.115736  131119  278152
#  Masters       43.074627  44.490312   23088   52810
#  Preschool     41.750000  43.228571     668    1513
#  Prof-school   40.195652  45.611570    3698   22076
#  Some-college  33.740556  37.017391   94676  166023

# %% [markdown]
# #### **9.2  Pivot Tables**
#
# `syntax = pd.pivot_table(data = x, index=x.education, values= ["age"], columns=x.sex, aggfunc=['mean'])`

# %%
pd.pivot_table(data = dk, index=dk.education, values= ["age"], columns=dk.sex, aggfunc=['mean'])

# %%
pd.pivot_table(data = dk, values= ["age", 'capitalGain', 'capitalLoss'], index=dk.education, columns=dk.sex,
               aggfunc={"age":"mean", 'capitalGain': "max", 'capitalLoss': 'min'})

# %%
pd.pivot_table(data = dk, values=["age", 'capitalGain', 'capitalLoss'], index=dk.education,
               columns = dk.sex, aggfunc={"age": "mean", 'capitalGain': ["mean", "sum", "max"], 'capitalLoss': 'sum'})

# %% [markdown]
# ### **10. Plotting Bars**

# %%
N = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data", header=None)
col = [                #Adding Column names in
        "age",
        "workclass",
        "fnlwgt",
        "education",
        "educationNum",
        "maritalStatus",
        "occupation",
        "relationship",
        "race",
        "sex",
        "capitalGain",
        "capitalLoss",
        "hoursPerWeek",
        "nativeCountry",
        "Above50K"
]
N.columns = col
N.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            32561 non-null  int64
#  1   workclass      32561 non-null  object
#  2   fnlwgt         32561 non-null  int64
#  3   education      32561 non-null  object
#  4   educationNum   32561 non-null  int64
#  5   maritalStatus  32561 non-null  object
#  6   occupation     32561 non-null  object
#  7   relationship   32561 non-null  object
#  8   race           32561 non-null  object
#  9   sex            32561 non-null  object
#  10  capitalGain    32561 non-null  int64
#  11  capitalLoss    32561 non-null  int64
#  12  hoursPerWeek   32561 non-null  int64
#  13  nativeCountry  32561 non-null  object
#  14  Above50K       32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
N.sex.value_counts().plot.barh()  #bar chart (horizontal)

# %%
N.workclass.value_counts().plot.hist()  #histogram

# %%
N.sex.value_counts().plot.pie();  #pie chart

# %% [markdown]
# ### **11. Data Input and Output**
#
# This notebook is the reference code for getting input and output, pandas can read a variety of file types using its pd.read_ methods. Let's take a look at the most common data types:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### **1. CSV**
#
# #### **CSV Input**

# %% [markdown]
# `df3 = pd.read_csv('adult.data')`

# %% [markdown]
# #### **CSV Output**

# %% [markdown]
# `df3.to_csv('example',index=False)`

# %% [markdown]
# #### **2. Excel**
#
# #### **Excel Input**

# %% [markdown]
# `pd.read_excel('Excel_Sample.xlsx',sheetname='Sheet1')`

# %% [markdown]
# #### **Excel Output**

# %% [markdown]
# `df.to_excel('Excel_Sample.xlsx',sheet_name='Sheet1')`

# %% [markdown]
# #### **3. HTML**
#
# You may need to install htmllib5,lxml, and BeautifulSoup4. In your terminal/command prompt run:
#
#     conda install lxml
#     conda install html5lib
#     conda install BeautifulSoup4
#
# Then restart Jupyter Notebook.
# (or use pip install if you aren't using the Anaconda Distribution)
#
# Pandas can read table tabs off of html. For example:

# %% [markdown]
# `df = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')`

# %% [markdown]
# #### **4. SQL (Optional)**
#
# * Note: If you are completely unfamiliar with SQL you can check out my other course: "Complete SQL Bootcamp" to learn SQL.

# %% [markdown]
# The pandas.io.sql module provides a collection of query wrappers to both facilitate data retrieval and to reduce dependency on DB-specific API. Database abstraction is provided by SQLAlchemy if installed. In addition you will need a driver library for your database. Examples of such drivers are psycopg2 for PostgreSQL or pymysql for MySQL. For SQLite this is included in Python’s standard library by default. You can find an overview of supported drivers for each SQL dialect in the SQLAlchemy docs.
#
#
# If SQLAlchemy is not installed, a fallback is only provided for sqlite (and for mysql for backwards compatibility, but this is deprecated and will be removed in a future version). This mode requires a Python database adapter which respect the Python DB-API.
#
# See also some cookbook examples for some advanced strategies.
#
# The key functions are:
#
# * read_sql_table(table_name, con[, schema, ...])
#     * Read SQL database table into a DataFrame.
# * read_sql_query(sql, con[, index_col, ...])
#     * Read SQL query into a DataFrame.
# * read_sql(sql, con[, index_col, ...])
#     * Read SQL query or database table into a DataFrame.
# * DataFrame.to_sql(name, con[, flavor, ...])
#     * Write records stored in a DataFrame to a SQL database.

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')

# %%
df.to_sql('data', engine)

# %%
sql_df = pd.read_sql('data',con=engine)

# %%
sql_df

# %% [markdown]
# ## Great Job!
