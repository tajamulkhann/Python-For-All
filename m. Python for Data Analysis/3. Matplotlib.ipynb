# %% [markdown]
# ## Matplotlib
#  stands for "Mathematical Plotting Library." It is a Python library used for creating static, animated, and interactive visualizations.
#
# ## Index
#
# 1. Introduction
#       * Data Visualisation (Basics of DV, Use if DV, Popular DV Libraries`)
#       * Matplotlib (Pros, Basic Commands, import Commands, Types of Plots, Anatomy)
# 2. Line Graph (Figure (figsize, DPI), Concept of Plot (Multi-Plots), Title, Labels, Grid, Ticks, Lim, legend(labels = x,y), Savefig)
#     * Plot Customization
#       * Color = MATLAB Color Codes, Simple Parameter Syntax, Concept of Alpha
#       * Lines = MATLAB Syntax, Color, Simple Parameter Syntax = Line Width (lw) , Line Style, Custom Dashes
#       * Markers = Marker Codes, Matlab Syntax [mec, mfc, ms], Basic Syntax (Symbols, Marker Size, Marker Color (Face, edge, width)
# 3. Sub Plots
#       * Functional Subplot
#       * Object Oriented Method
#       * Add Custom Axes Method (Axes within Axes lbwh concept and plot),
#       * Advanced Subplots Method, (Concept of Axes, (1D & 2D), titles, Concept of Tight Layout)
# 4. Plotting Figures (Loading Data Set, Bar/h chart, Histogram, Scatter Plot,Box Plot, Violin, Pie)
# 5. Further Reading

# %% [markdown]
# ### **1. Introduction**

# %% [markdown]
# #### **1.1 Data Visualization**
#
# `A graphical/pictorial representation of information and data.`

# %% [markdown]
# **Use of Data Visualization**
#
# ---
#
# 1. view changes over time seamlessly
# 2. discover correlations between 2 or more variables.
# 3. simplify complex information into user friendly formats
# 4. can tell a better story with a bunch of pictures

# %% [markdown]
# **Popular DV Libraries in Python**
#
# ---
#
# 1. Matplotlib
# 2. Seaborn
# 3. Plotly
# 4. ggplot2 etc

# %% [markdown]
# ### **1.2 Matplotlib**

# %% [markdown]
# Matplotlib is the "grandfather" open source library of data visualization with Python. It was created to replicate MatLab's plotting capabilities in Python.
#
# * Matplotlib is a low level graph plotting library in python that serves as a visualization utility.
#
# * It is an alternate to MATLAB as it is completely open source.
#
# * Matplotlib was created by John D. Hunter.

# %% [markdown]
# #### **Pros**
#
# ---
#
# * Generally easy to get started for simple plots
# * Support for custom labels and texts
# * Great control of every element in a figure
# * High-quality output in many formats
# * Very customizable in general
# * Matplotlib allows you to create reproducible figures programmatically.

# %% [markdown]
# #### **Basic Commands**
#
# ---

# %% [markdown]
# * `! pip install matplotlib`
# * `! pip uninstall matplotlib`
# * `! pip show matplotlib`
# * `! pip install --upgrade matplotlib`
# * `matplotlib.__version__`

# %% [markdown]
# #### **Import Commands**
#
# ---

# %% [markdown]
# * `! pip install names`
# * `import matplotlib.pyplot as plt`
# * `import random`
# * `import numpy as np`
# * `import pandas as pd`
# * `import names`

# %% [markdown]
# #### **Types of Plot**
#
# ---
# 1. Line
# 2. Bar
# 3. Scatter
# 4. Histogram
# 5. Image plot
# 6. Box plot
# 7. Violin plot
# 8. Stream
# 9. Quiver
# 10. Area
# 11. Pie
# 12. Donut

# %% [markdown]
# ![download.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![download (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### **Anatomy of Matplots**
#
# ---

# %% [markdown]
# ![download (2).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **2. Line Graph**
#
# `plt.plot` = Line Chart
#
# * It is used to compare less than 25 numbers.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
height = np.random.randint(70, 191, (5))
weight = np.random.randint(80, 121, (5))
age =    np.random.randint(25, 30, (5))
salary = np.random.randint(20000, 30000, (5))

# %%
height
# Out:
# array([113, 135, 160,  79,  96])

# %%
weight
# Out:
# array([108, 100,  86, 114, 116])

# %%
age
# Out:
# array([25, 26, 26, 28, 26])

# %%
salary
# Out:
# array([25952, 22373, 26534, 27250, 25899])

# %% [markdown]
# #### **plt.figure( )**
#
# ---
#
# `is a tuple of the width and height of the figure in inches`

# %% [markdown]
# **figsize**

# %%
# Line Chart = plt.plot
fig = plt.figure(figsize = (5,5), dpi = 200); #Speciy dpi at start of while saving

#Either use ; or plt.show()

# %% [markdown]
# **dpi** =  *finer font*
# `is the dots-per-inch (pixel per inch).`

# %%
fig.savefig("filename.png", dpi=200) #fig = figure name

# %% [markdown]
# #### **plt.plot( )**
#
# ---

# %%
# Line Chart
plt.plot(height, weight); # Will hide the object ID info

# %% [markdown]
# **Multi-plots**

# %%
plt.plot(height, weight)
plt.plot(height, age)
plt.legend(labels = ['Weight', 'age']);

# %% [markdown]
# #### **plt.title( ) , plt.label( )**
#
# ---

# %%
# Line Chart
plt.title("Relationship between Height vs Weight")
plt.plot(height, weight)
plt.xlabel("Height")
plt.ylabel("Weight");

# %% [markdown]
# #### **plt.plot( ) Customization**
#
# ---

# %% [markdown]
# ![download (3).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### **MATLAB Color codes**
#
#
# * k - black
# * b - blue
# * orange for orange
# * m - magenta
# * c - cyan
# * y - yellow
# * r - red
# * g - green
# * w - white

# %% [markdown]
# #### **Color = Parameter Codes**

# %% [markdown]
# We can also define colors by their names or RGB hex codes and optionally provide an alpha value using the color and alpha keyword arguments. Alpha indicates opacity.
#
#
# ```
# color="blue"
# color="#8B008B"
# color="#FF8C00"
# ```

# %% [markdown]
# ![wz6d9yz2xhms0yhi71s8.webp](data:image/webp;base64,...)

# %%
# Line Chart
plt.title("Relationship between Height vs Weight")
plt.plot(height, weight, "r") #Color
plt.xlabel("Height")
plt.ylabel("Weight");

# %% [markdown]
# **Alpha**
#
# ---
#
#
#
# `intensity of color`

# %%
plt.plot(height, weight, alpha = -2.3)

# %% [markdown]
# #### **Lines**
#
# ---

# %% [markdown]
# ![download (4).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **MATLAB Syntax**

# %%
plt.title("Relationship between Height vs Weight")
plt.plot(height, weight, "r--^") #Color, line, Markings

# %%
# Line Chart
plt.title("Relationship between Height vs Weight")
plt.plot(height, weight, "r--o")
plt.xlabel("Height")
plt.ylabel("Weight");

# %%
# Line Chart
plt.title("Relationship between Height vs Weight")
plt.plot(height, weight, "r*")
plt.xlabel("Height")
plt.ylabel("Weight");

# %% [markdown]
# **Easy Syntax**

# %% [markdown]
# **1. Color**
# ```
# color = 'red'
# color = "green"
# color = "black"
# color = "blue"
# color = "purple"
#
# ```

# %% [markdown]
# **2. Line Width** `lw`
#
# ```
# linewidth=0.25
# lw=3
# ```

# %% [markdown]
# **3. Line Style** `ls`
#
# Possible linestype options : `‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’`

# %% [markdown]
# **4. Custom Dashes**
#
# `line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...`

# %% [markdown]
# #### **Markers**
#
# ---

# %% [markdown]
# **Marker Codes**
#
# ` ^ - Upper traingle`
#
# ` v - Inverted traingle`
#
# ` > - Right side traingle`
#
# ` < - Left side traingle`
#
# ` o - Circle`
#
# ` * - star`
#
# ` d - Square`
#
# ` -- - dashed line`
#
# ` --. - dashed with dottted line`
#
# ` . - dotted lines -->`

# %% [markdown]
# **Using MATLAB Syntax**

# %%
# Line Chart
plt.title("Relationship between Height vs Weight")
plt.plot(height, weight, "r--*", mec = 'g', mfc = 'b', ms = 10) # mec - Marker Edge color , MFC - Marker face color, ms - marker size
plt.xlabel("Height")
plt.ylabel("Weight");

# %%
# Line Chart
plt.title("Relationship between Height vs Weight")
plt.plot(height, weight, "r--o")
plt.xlabel("Height")
plt.ylabel("Weight");

# %%
# Line Chart
plt.figure(figsize = (15, 5)) #width, height
plt.title("Relationship between Height vs Weight")
plt.plot(height, weight, "r--o")
plt.xlabel("Height")
plt.ylabel("Weight");

# %% [markdown]
# **Easy Marking Syntax**
#
#
#
# ---

# %% [markdown]
# **1. Marker**
#
# possible marker symbols: `'+', 'o', '*', 's', ',', '.', '1', '2', '3', '4'`
#
# `marker = '*'`

# %% [markdown]
# **2. Marker Size**
#
# `markersize=2`

# %% [markdown]
# **3. Marker Color**
#
#
# ```
# markerfacecolor = 'red'
# markeredgecolor = 'green'
# markerwidth = 3
# ```

# %% [markdown]
# #### **plt.savefig ( )**
#
# ---

# %%
# Line Chart
plt.figure(figsize = (15, 5)) #width, height
plt.title("Relationship between Height vs Weight")
plt.plot(height, weight, "r--o")
plt.xlabel("Height")
plt.ylabel("Weight")
# plt.savefig("Relationship between Height vs Weight.jpg") #png, jpg
# Out:
# Text(0, 0.5, 'Weight')

# %%
# Line Chart
plt.figure(figsize = (15, 5)) #width, height
plt.title("Relationship between Height vs Weight")
plt.plot(height, weight, "r--o")
plt.xlabel("Height")
plt.ylabel("Weight")
plt.savefig("Height and Weight.jpg") #png, jpg

# %% [markdown]
# ### **plt.grid ( )**
#
# ---

# %%
# Line Chart
plt.figure(figsize = (15, 5)) #width, height
plt.title("Relationship between Height vs Weight")
plt.plot(height, weight, "r--o")
plt.xlabel("Height")
plt.ylabel("Weight")
plt.grid()
plt.savefig("Height and Weight.jpg") #png, jpg

# %%
height
# Out:
# array([113, 135, 160,  79,  96])

# %%
weight
# Out:
# array([108, 100,  86, 114, 116])

# %%
list(range(90, 170, 10))
# Out:
# [90, 100, 110, 120, 130, 140, 150, 160]

# %% [markdown]
# ### **plt.lim ( )**
#
# ---
#
#
#
# `limitting view as per x-axis or y-axis`

# %%
# Line Chart
plt.figure(figsize = (15, 5)) #width, height
plt.title("Relationship between Height vs Weight")
plt.plot(height, weight, "r--o")
plt.xlabel("Height")
plt.ylabel("Weight")
plt.xlim(90, 170) #To limit the spread
plt.ylim(10, 130)
plt.xticks(np.arange(90, 170, 10))
plt.yticks(np.arange(10, 130, 10));

# %%
height
# Out:
# array([113, 135, 160,  79,  96])

# %%
plt.plot(height, weight);

# %%
plt.plot(height, weight)
plt.xlim(70, 150)
# Out:
# (70.0, 150.0)

# %% [markdown]
# ### **plt.ticks ( )**
#
# ---
#
#
#
# `intervals between 1st and 2nd value`

# %%
# Line Chart
plt.figure(figsize = (15, 5)) #width, height
plt.title("Relationship between Height vs Weight")
plt.plot(height, weight, "r--o")
plt.xlabel("Height")
plt.ylabel("Weight")
plt.xticks(np.arange(90, 170, 5))
plt.yticks(np.arange(10, 130, 10));

# %%
height
# Out:
# array([113, 135, 160,  79,  96])

# %%
weight
# Out:
# array([108, 100,  86, 114, 116])

# %%
age
# Out:
# array([25, 26, 26, 28, 26])

# %%
plt.plot(height, weight)
plt.plot(height, age)
plt.legend(labels = ['weight', 'age']);

# %%
plt.plot(height, weight)
plt.plot(height, age)
plt.xlabel("Height")
plt.ylabel("Weight and age")
plt.legend(labels = ['Weight', 'age']);

# %% [markdown]
# ### **plt.legend ( )**
#
# ---

# %% [markdown]
# ![Screenshot 2022-09-03 191235.jpg](data:image/jpeg;base64,...)

# %%
plt.plot(height, weight)
plt.plot(height, age)
plt.xlabel("Height")
plt.ylabel("Weight and age")
plt.legend(labels = ['Weight', 'age'], loc = 'upper left'); # Lower Left, Upper Left, upper right

# %% [markdown]
# ## **3. Subplots**
#
# `subplots method provides a way to plot multiple plots on a single figure.`
#
# * Use any command with the help of `set_`

# %% [markdown]
# ### **Functional Subplot**  `Doubt`
#
# `Creating Multiplots on Same Canvas`

# %%
import numpy as np
import matplotlib.pyplot as plt

q = np.arange(0,10,1)
w = 2*q + 5
e = 3*q + 10

plt.subplot(1,2,1)   # 1 rows , 2 col, plot Number
plt.plot(q,w, 'b--*')
plt.title("graph1")

plt.subplot(1,2,2)    # 1 rows , 2 col, plot Number
plt.plot(q,e)
plt.title("graph2");

# %% [markdown]
# ### **Object Oriented Subplots**  `(API Method)`
#
# The main idea in using the more formal Object Oriented method is to create figure objects and then just call methods or attributes off of that object. This approach is nicer when dealing with a canvas that has multiple plots on it.
#
# To begin we create a figure instance. Then we can add axes to that figure:

# %% [markdown]
# ![Yay.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### **Adding Custom Axes In Empty Canvas** `Method`

# %%
fig1 = plt.figure()

custom_axes = fig1.add_axes([0.1,0.1,0.8,0.8]) #left, bottom, width, height of axes
custom_axes.plot(q,w, 'b--*')
custom_axes.set_xlabel = 'yay';

# %% [markdown]
# **Understanding syntax of Add Axes**  `lbwh concept`

# %%
fig2 = plt.figure(figsize=(5,5))
custom_axesa = fig2.add_axes([0.1,0.1,0.8,0.8]) #main Axes
custom_axesb = fig2.add_axes([0.2,0.5,0.4,0.3]) #Axes with in main axes

# %% [markdown]
#  Values always starts from 0 to 1
#  ```
# 0.2 = Starts a 25% Left from 0 point
# 0.5 = Starts from bottom at 50 % height of canvas
# 0.4 = spreads to 50% of width of canvas
# 0.3 = spreads to 100% of length of canvas
# ```

# %% [markdown]
# **Plot in Added Axes**
#
# ---

# %%
fig2 = plt.figure(figsize=(5,5))
custom_axes1 = fig2.add_axes([0.1,0.1,0.8,0.8]) #main Axes
custom_axes1.set_title('Big Plot')
custom_axes2 = fig2.add_axes([0.2,0.5,0.4,0.3])
custom_axes2.set_title('Small Plot')
custom_axes1.plot(q,'k--*')
custom_axes2.plot(e);

# %% [markdown]
# #### **Object Oriented Advanced Subplots**

# %% [markdown]
# Code is a little more complicated, but the advantage is that we now have full control of where the plot axes are placed, and we can easily add more than one axis to the figure:

# %% [markdown]
# * Syntax
#
# ```
# fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize = (n,n))
#
# ax[0, 0].plot(x, 'c-o')
# ax[0, 1].plot(y, 'g-*')
# ax[1, 0].plot(z, 'k^')
# ax[1, 1].plot(a, z, 'b-d')
#
# ax[0, 0].set_title("Title")
# ax[0, 1].set_title("Title")
# ax[1, 0].set_title("Title")
# ax[1, 1].set_title("Title");
#
# ```

# %% [markdown]
# **1. Simple Structure**
#
# `Same Like Adding Axes in empty Canvas`

# %%
fig, ax = plt.subplots()
ax.plot(q,e);

# %% [markdown]
# **2. Advance Structure**
#
# `The Main Advantage is specifying as many nrows and ncols as we want`

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize = (15,7))
 #specify rows and cols as many rows

ax[0,0].plot(height, 'c-o')
ax[0, 1].plot(weight, 'g-*')
ax[1, 0].plot(age, 'k^')
ax[1, 1].plot(salary, age, 'b-d')

ax[0, 0].set_title("Dist of Height")
ax[0, 1].set_title("Dist of weight")
ax[1, 0].set_title("Dist of calories")
ax[1, 1].set_title("Dist of height, weight");

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (15,7))
 #specify rows and cols as many rows

ax[0].plot(height, age, color = 'blue')
ax[1].plot(weight,salary, 'g-*')

ax[1].set_title("Dist of calories")
ax[0].set_title("Dist of height, weight")

ax[0].legend(labels = ['height','age']);

# %% [markdown]
# **subplots()**
# The plt.subplots() object will act as a more automatic axis manager.
#
# Basic use cases:

# %%
# Use similar to plt.figure() except use tuple unpacking to grab fig and axes
fig, axes = plt.subplots()

# Now use the axes object to add stuff to plot
axes.plot(height, weight, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title');

# %% [markdown]
# A common issue with matplolib is overlapping subplots or figures. We ca use fig.tight_layout() or plt.tight_layout() method, which automatically adjusts the positions of the axes on the figure canvas so that there is no overlapping content:

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize = (15,7))

ax[0, 0].plot(height, 'c-o')
ax[0, 1].plot(weight, 'g-*')
ax[0, 0].legend(labels =['height'])
ax[1, 0].plot(age, 'k^')
ax[1, 1].plot(salary, age, 'b-d')

ax[0, 0].set_title("Dist of Height")
ax[0, 1].set_title("Dist of weight")
ax[1, 0].set_title("Dist of calories")
ax[1, 1].set_title("Dist of height, weight")

plt.tight_layout();

# %% [markdown]
# #### **Problem**
#
# Notice how are legend overlaps some of the actual plot!
#
# The legend function takes an optional keyword argument loc that can be used to specify where in the figure the legend is to be drawn. The allowed values of loc are numerical codes for the various places the legend can be drawn. See the documentation page for details. Some of the most common loc values are:

# %%
# Lots of options....

ax.legend(loc=1) # upper right corner
ax.legend(loc=2) # upper left corner
ax.legend(loc=3) # lower left corner
ax.legend(loc=4) # lower right corner

# .. many more options are available

# Most common to choose
ax.legend(loc=0) # let matplotlib decide the optimal location
fig

# %% [markdown]
# ## **4. Plotting Figures**

# %% [markdown]
# #### **Loading a Table**

# %%
tk = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data", header=None)
col = [                #Adding Column names in
        "age",
        "workclass",
        "fnlwgt",
        "education",
        "educationNum",
        "maritalStatus",
        "occupation",
        "relationship",
        "race",
        "sex",
        "capitalGain",
        "capitalLoss",
        "hoursPerWeek",
        "nativeCountry",
        "Above50K"
]
tk.columns = col
tk.sample(3)
# Out:
#        age   workclass  fnlwgt education  educationNum        maritalStatus  \
# 3667    37     Private  262409   Masters            14             Divorced
# 23927   27     Private  491421   5th-6th             3        Never-married
# 6121    45   Local-gov  236586   Masters            14   Married-civ-spouse
#
#              occupation relationship    race      sex  capitalGain  \
# 3667    Exec-managerial    Unmarried   White   Female            0
# 23927   Farming-fishing    Unmarried   White     Male            0
# 6121     Prof-specialty      Husband   White     Male         7688
#
#        capitalLoss  hoursPerWeek   nativeCountry Above50K
# 3667           213            45   United-States    <=50K
# 23927            0            50   United-States    <=50K
# 6121             0            55   United-States     >50K

# %% [markdown]
# ### **1. Bar Chart** `Comparison`

# %%
# Creating Data
fruits = {'mango':60,'apple':100,'banana':30,'orange':40}
x = list(fruits.keys())
y = list(fruits.values())

fig = plt.figure(figsize=(10,5))
plt.barh(x,y,color='r')
plt.title("Fruits")
plt.xlabel('fruits')
plt.ylabel('Price')
plt.show()

# %%
T = tk.education.value_counts()
F = tk.workclass.value_counts()

# %%
J = T.index

# %%
plt.figure(figsize = (10, 5))
plt.title("Comparison between Education Categories")
plt.barh(J,T,color = ['r', 'g', 'b', 'orange', 'c'])
plt.grid();

# %% [markdown]
# ### **2. Histogram** `Distribution`

# %%
# histogram
plt.figure(figsize = (10, 5))
plt.hist(tk.age.value_counts(), color = ['c'])
plt.ylabel("Distribution of Ages")
plt.grid();

# %% [markdown]
# ### **3. Scatter Plot** `Relationship`
#
# Scatter plots are used to plot data points on a horizontal and a vertical axis To determine whether or not two variables have a relationship or correlation

# %%
# Creating data
x=[10,20,30,40,50,60,70,80]
a=[2,3,4,9,7,5,6,1]
b=[9,7,6,5,4,3,2,3]

#create scatter plot
plt.scatter(x,a,color='m',alpha=0.5,edgecolors='k',marker='o',s=100)
plt.scatter(x,b,color='y',alpha=0.5,edgecolors='k',marker='D',s=100)
plt.legend([a,b])
plt.title('Scatter')
plt.xlabel('x')
plt.ylabel('a,b')
plt.grid()
plt.savefig("Scatter plot.png")
plt.show()

# %%
plt.figure(figsize = (10, 5))
plt.scatter(tk['workclass'][:100], tk.education[:100], color = 'c', marker = '*', s = 50)
plt.grid();

# %% [markdown]
# ### **4. Boxplot** `Distribution of Numerical Values`
#
# A boxplot summarizes the distribution of a numeric variable for one or several groups. It allows to quickly get the median, quartiles and outliers but also hides the dataset individual data points

# %%
# creating data
total = [10,20,3,40,50]
order = [20,30,60,4,80]
discount=[3,4,45,27,60]
data= list([total,order,discount])
plt.boxplot(data,showmeans=True)
plt.show()

# %%
plt.figure(figsize = (10, 5))
plt.boxplot(F)
plt.grid();

# %% [markdown]
# ### **5. Violinplot** `Attractive Version of Box Plot`
#
# A violin plot is similar to  whisker or box plot do. As it shows several quantitative data across one or more categorical variables. It can be an effective and attractive way to show multiple data.

# %%
# creating data
total = [10,20,3,40,50]
order = [20,30,60,4,80]
discount=[3,4,45,27,60]
data= list([total,order,discount])
plt.violinplot(data,showmeans=True)
plt.show()

# %%
plt.figure(figsize = (10, 5))
plt.violinplot(tk['age'])
plt.grid();

# %% [markdown]
# ### **6. Pie Chart** `represents Data in percents`

# %%
fruits = {'mango':60,'apple':100,'banana':30,'orange':40}
x = list(fruits.keys())
y = list(fruits.values())
plt.pie(y,labels=x,autopct='%1.1f%%',startangle=90,shadow=True)
plt.show()

# %%
D = tk.education.value_counts()
K = D.index

# %%
plt.figure(figsize = (10, 10))
plt.pie(D,labels = K);

# %% [markdown]
# ## **5. Further Reading**

# %% [markdown]
# http://www.matplotlib.org - The project web page for matplotlib.
#
#
# https://github.com/matplotlib/matplotlib - The source code for matplotlib.
#
#
# http://matplotlib.org/gallery.html - A large gallery showcaseing various types of plots matplotlib can create. Highly recommended!
#
#
# http://www.loria.fr/~rougier/teaching/matplotlib - A good matplotlib tutorial.
#
#
# http://scipy-lectures.github.io/matplotlib/matplotlib.html - Another good matplotlib reference.
